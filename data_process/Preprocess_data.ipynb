# %%
import time
import re
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from sklearn.preprocessing import LabelEncoder

import scipy
from scipy.sparse import csr_matrix

data_path = './data/'
if not os.path.exists(data_path):
    os.makedirs(data_path)

# %% [markdown]
# ## Loading Data

# %%
start_time = time.time()
business = pd.read_json("../yelp_dataset/yelp_academic_dataset_business.json", 
                      orient = 'records',
                      lines = True, chunksize = 10000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 2.21366810798645

# %%
display(business.head())
print(business.shape)
print("Number of business:  {}".format(business['business_id'].nunique()))
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3        1  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
#
#                                           categories  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2  Antiques, Fashion, Used, Vintage & Consignment...
# 3                         Beauty & Spas, Hair Salons
# 4  Gyms, Active Life, Interval Training Gyms, Fit...
#
#                                                hours
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                               None
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# (160585, 14)
# Number of business:  160585

# %%
restaurants = business.loc[business['categories'].apply(lambda x: False if x is None else 'Restaurants' in x ),].copy()
print('Number of restaurants:  ', restaurants.shape[0])
# Out:
# Number of restaurants:   50763

# %% [markdown]
# ### Review

# %%
start_time = time.time()
reviews = pd.read_json("../yelp_dataset/yelp_academic_dataset_review.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 69.77719354629517

# %%
display(reviews.head())
print(reviews.shape)
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2  NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4  sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
#
#    stars  useful  funny  cool  \
# 0      4       3      1     1
# 1      4       1      0     0
# 2      5       0      0     0
# 3      2       1      1     1
# 4      4       0      0     0
#
#                                                 text                date
# 0  Apparently Prides Osteria had a rough summer a... 2014-10-11 03:34:02
# 1  This store is pretty good. Not as great as Wal... 2015-07-03 20:38:25
# 2  I called WVM on the recommendation of a couple... 2013-05-28 20:38:06
# 3  I've stayed at many Marriott and Renaissance M... 2010-01-08 02:29:15
# 4  The food is always great here. The service fro... 2011-07-28 18:05:01
# (8635403, 9)

# %%
rreviews = reviews[reviews['business_id'].isin(restaurants['business_id'])]
print(rreviews.shape)
# Out:
# (5574795, 9)

# %% [markdown]
# ### User

# %%
start_time = time.time()
users = pd.read_json("../yelp_dataset/yelp_academic_dataset_user.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 38.17113542556763

# %%
display(users.head())
print(users.shape)
print("Number of Users:  {}".format(users['user_id'].nunique()))
# Out:
#                   user_id       name  review_count        yelping_since  \
# 0  q_QQ5kBBwlCcbL1s4NVK3g       Jane          1220  2005-03-14 20:26:35
# 1  dIIKEfOgo0KqUfGQvGikPg       Gabi          2136  2007-08-10 19:01:51
# 2  D6ErcUnFALnCQN4b1W_TlA      Jason           119  2007-02-07 15:47:53
# 3  JnPIjvC0cmooNDfsa9BmXg        Kat           987  2009-02-09 16:14:29
# 4  37Hc8hr3cw0iHLoPzLK6Ow  Christine           495  2008-03-03 04:57:05
#
#    useful  funny   cool                                              elite  \
# 0   15038  10030  11291       2006,2007,2008,2009,2010,2011,2012,2013,2014
# 1   21272  10289  18046  2007,2008,2009,2010,2011,2012,2013,2014,2015,2...
# 2     188    128    130                                          2010,2011
# 3    7234   4722   4035                      2009,2010,2011,2012,2013,2014
# 4    1577    727   1124                                     2009,2010,2011
#
#                                              friends  fans  ...  \
# 0  xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357  ...
# 1  XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...  1025  ...
# 2  GfB6sC4NJQvSI2ewbQrDNA, jhZtzZNNZJOU2YSZ6jPlXQ...    16  ...
# 3  HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...   420  ...
# 4  -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...    47  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0              163                 190              361              147
# 1               87                  94              232               96
# 2                1                   3                0                0
# 3              129                  93              219               90
# 4               19                  32               16               15
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0             1212              5691             2541              2541
# 1             1187              3293             2205              2205
# 2                5                20               31                31
# 3             1120              4510             1566              1566
# 4               77               131              310               310
#
#    compliment_writer  compliment_photos
# 0                815                323
# 1                472                294
# 2                  3                  1
# 3                391                326
# 4                 98                 44
#
# [5 rows x 22 columns]
# (2189457, 22)
# Number of Users:  2189457

# %%
rusers = users[users['user_id'].isin(rreviews['user_id'].unique())]
print(rusers.shape)
# Out:
# (1551310, 22)

# %% [markdown]
# ### Tips

# %%
start_time = time.time()
tips = pd.read_json("../yelp_dataset/yelp_academic_dataset_tip.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 4.816680908203125

# %%
display(tips.head())
print(tips.shape)
# Out:
#                   user_id             business_id  \
# 0  WCjg0jdHXMlwbqS9tZUx8Q  ENwBByjpoa5Gg7tKgxqwLg
# 1  42-Z02y9bABShAGZhuSzrQ  jKO4Og6ucdX2-YCTKQVYjg
# 2  5u7E3LYp_3eB8dLuUBazXQ  9Bto7mky640ocgezVKSfVg
# 3  wDWoMG5N9oI4DJ-p7z8EBg  XWFjKtRGZ9khRGtGg2ZvaA
# 4  JmuFlorjjRshHTKzTwNtgg  mkrx0VhSMU3p3uhyJGCoWA
#
#                                                 text                date  \
# 0                               Carne asada chips... 2011-07-22 19:07:35
# 1  Best happy hour from 3pm to 6pm! $1 off martin... 2014-09-10 07:33:29
# 2  Nice people, skilled staff, clean location - b... 2013-12-13 23:23:41
# 3  1/2-price bowling & the "Very" Old Fashion are... 2017-07-11 23:07:16
# 4  Solid gold's. Great sauna. Great staff, too. E... 2016-11-30 08:46:36
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# (1162119, 5)

# %%
rtips = tips[tips['business_id'].isin(restaurants['business_id'])]
print(rtips.shape)
# Out:
# (810577, 5)

# %% [markdown]
# ## Taking Subsets

# %%
sparsity_score = lambda r, u, b: r.shape[0] / (u.shape[0] * b.shape[0])
print("Current sparsity:  ", sparsity_score(rreviews, rusers, restaurants))
# Out:
# Current sparsity:   7.079181214365046e-05

# %%
# print(restaurants['review_count'].describe())
# plt.plot(np.arange(0, 1, 0.001), np.quantile(restaurants['review_count'], np.arange(0, 1, 0.001)))

# %%
# Users leave more than 10 reviews
# Restaurants at least receive 114 (third quantile) reviews

# Users leave more than 50 reviews
# Restaurants at least receive 500 (third quantile) reviews

# Subset restaurants
restaurants_sub = restaurants[restaurants['review_count'] > 500]
state_count = restaurants.groupby(['state'])['business_id'].count()
restaurants_sub = restaurants_sub[restaurants_sub['state'].isin(state_count.index[state_count > 5])]
rreviews_business = rreviews[rreviews['business_id'].isin(restaurants_sub['business_id'])]

# Subset Users
user_review_count = rreviews_business.groupby(['user_id'])['review_id'].count()
rusers_sub = rusers[rusers['user_id'].isin(user_review_count.index[user_review_count > 50])]

# Subset Reviews
rreviews_users = rreviews[rreviews['user_id'].isin(user_review_count.index[user_review_count > 50])]
rreviews_union = rreviews.loc[set(rreviews_business.index).union(rreviews_users.index), ]
rreviews_inter = rreviews.loc[set(rreviews_business.index).intersection(rreviews_users.index), ]


# Subset tips
tips_business = tips[tips['business_id'].isin(restaurants_sub['business_id'])]
tips_users = tips[tips['user_id'].isin(rusers_sub['user_id'])]
tips_union = tips.loc[set(tips_business.index).union(set(tips_users.index)),]

print("Number of restaurants:  ", restaurants_sub.shape[0])
print("Number of users:  ", rusers_sub.shape[0])
print("Number of reviews:  ", rreviews_inter.shape[0])
print("Sparsity:  ", sparsity_score(rreviews_inter, rusers_sub, restaurants_sub))
# Out:
# Number of restaurants:   1702
# Number of users:   908
# Number of reviews:   67167
# Sparsity:   0.04346208399550671

# %% [markdown]
# ## Preprocess Restaurants

# %% [markdown]
# ### Separting Restaurants Attributes

# %%
attributes = defaultdict(int)
for i in restaurants_sub['attributes'].apply(lambda x: None if x is None else x.keys()):
    if i is not None:
        for k in i:
            attributes[k] += 1
attributes
# Out:
# defaultdict(int,
#             {'NoiseLevel': 1687,
#              'BikeParking': 1678,
#              'RestaurantsAttire': 1677,
#              'BusinessAcceptsCreditCards': 1658,
#              'BusinessParking': 1697,
#              'RestaurantsReservations': 1679,
#              'GoodForKids': 1691,
#              'RestaurantsTakeOut': 1694,
#              'Caters': 1681,
#              'WiFi': 1688,
#              'RestaurantsDelivery': 1696,
#              'HasTV': 1676,
#              'RestaurantsPriceRange2': 1701,
#              'Alcohol': 1686,
#              'Music': 560,
#              'BusinessAcceptsBitcoin': 534,
#              'GoodForDancing': 502,
#              'DogsAllowed': 1341,
#              'BestNights': 541,
#              'RestaurantsGoodForGroups': 1685,
#              'OutdoorSeating': 1687,
#              'HappyHour': 1246,
#              'RestaurantsTableService': 1147,
#              'GoodForMeal': 1635,
#              'WheelchairAccessible': 841,
#              'Ambience': 1677,
#              'BYOBCorkage': 524,
#              'ByAppointmentOnly': 576,
#              'Corkage': 470,
#              'BYOB': 336,
#              'Smoking': 364,
#              'CoatCheck': 416,
#              'DriveThru': 302,
#              'RestaurantsCounterService': 9,
#              'Open24Hours': 8,
#              'DietaryRestrictions': 10,
#              'AgesAllowed': 1})

# %%
# Select attributes having more than 1000 restaurants

selected_attributes = [k for k in attributes if attributes[k] > restaurants_sub.shape[0] * 0.3]
print("selected attributes:  ", selected_attributes)
for at in selected_attributes:
    restaurants["{}_{}".format('attr', at)] = 0
    selected_idx = restaurants_sub['categories'].apply(lambda x: False if x is None else at in x)
    restaurants_sub.loc[selected_idx, "{}_{}".format('attr', at)] = 1
# Out:
# selected attributes:   ['NoiseLevel', 'BikeParking', 'RestaurantsAttire', 'BusinessAcceptsCreditCards', 'BusinessParking', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsTakeOut', 'Caters', 'WiFi', 'RestaurantsDelivery', 'HasTV', 'RestaurantsPriceRange2', 'Alcohol', 'Music', 'BusinessAcceptsBitcoin', 'DogsAllowed', 'BestNights', 'RestaurantsGoodForGroups', 'OutdoorSeating', 'HappyHour', 'RestaurantsTableService', 'GoodForMeal', 'WheelchairAccessible', 'Ambience', 'BYOBCorkage', 'ByAppointmentOnly']

# %%
restaurants_sub.head()
# Out:
#                 business_id                            name  \
# 29   jGennaZUr2MsJyRhijNBfA                 Legal Sea Foods
# 113  XDv29FffNd2dWnDOtZP-wg                   Sapporo Ramen
# 147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 149  vecuat0jOia-CJveW3ngDw          Schmidt's Sausage Haus
# 312  6Y0lQh4O-9JCutgyuMNq0g                       Loca Luna
#
#                       address       city state postal_code   latitude  \
# 29            1 Harborside Dr     Boston    MA       02128  42.363442
# 113    1815 Massachusetts Ave  Cambridge    MA       02140  42.387212
# 147  216 Ponce De Leon Ave NE    Atlanta    GA       30308  33.772758
# 149          240 E Kossuth St   Columbus    OH       43206  39.946268
# 312      550 Amsterdam Ave NE    Atlanta    GA       30306  33.788608
#
#      longitude  stars  review_count  ...  attr_HappyHour  \
# 29  -71.025781    3.5           856  ...             NaN
# 113 -71.118532    3.5           635  ...             NaN
# 147 -84.380375    4.0          1001  ...             NaN
# 149 -82.991044    4.0          1354  ...             NaN
# 312 -84.369091    3.5           658  ...             NaN
#
#     attr_RestaurantsTableService attr_GoodForMeal attr_Ambience  attr_Music  \
# 29                           NaN              NaN           NaN         NaN
# 113                          NaN              NaN           NaN         NaN
# 147                          NaN              NaN           NaN         NaN
# 149                          NaN              NaN           NaN         NaN
# 312                          NaN              NaN           NaN         NaN
#
#      attr_BusinessAcceptsBitcoin  attr_BestNights  attr_WheelchairAccessible  \
# 29                           NaN              NaN                        NaN
# 113                          NaN              NaN                        NaN
# 147                          NaN              NaN                        NaN
# 149                          NaN              NaN                        NaN
# 312                          NaN              NaN                        NaN
#
#      attr_BYOBCorkage  attr_ByAppointmentOnly
# 29                NaN                     NaN
# 113               NaN                     NaN
# 147               NaN                     NaN
# 149               NaN                     NaN
# 312               NaN                     NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Separating Restaurants Categories

# %%
category_dict = defaultdict(int)
for cat in restaurants_sub['categories']:
    for c in cat.split(','):
        category_dict[c.strip()] += 1
sorted(category_dict.items(), key=lambda x: x[1], reverse = True)
# Out:
# [('Restaurants', 1702),
#  ('Nightlife', 686),
#  ('Bars', 654),
#  ('Food', 571),
#  ('American (New)', 443),
#  ('Breakfast & Brunch', 378),
#  ('American (Traditional)', 357),
#  ('Seafood', 238),
#  ('Sandwiches', 202),
#  ('Cocktail Bars', 186),
#  ('Mexican', 160),
#  ('Event Planning & Services', 158),
#  ('Burgers', 146),
#  ('Italian', 145),
#  ('Coffee & Tea', 129),
#  ('Japanese', 126),
#  ('Vegetarian', 125),
#  ('Desserts', 115),
#  ('Wine Bars', 113),
#  ('Pizza', 112),
#  ('Beer', 108),
#  ('Wine & Spirits', 108),
#  ('Southern', 107),
#  ('Sushi Bars', 103),
#  ('Asian Fusion', 102),
#  ('Steakhouses', 100),
#  ('Specialty Food', 93),
#  ('Salad', 92),
#  ('Barbeque', 89),
#  ('Cafes', 87),
#  ('Gluten-Free', 86),
#  ('Bakeries', 83),
#  ('Venues & Event Spaces', 81),
#  ('Diners', 78),
#  ('Pubs', 77),
#  ('Arts & Entertainment', 73),
#  ('Lounges', 72),
#  ('Caterers', 71),
#  ('Chinese', 70),
#  ('Tex-Mex', 70),
#  ('Vegan', 65),
#  ('Thai', 62),
#  ('Tapas/Small Plates', 55),
#  ('Gastropubs', 54),
#  ('French', 54),
#  ('Noodles', 51),
#  ('Tapas Bars', 50),
#  ('Beer Bar', 49),
#  ('Cajun/Creole', 47),
#  ('Comfort Food', 46),
#  ('Sports Bars', 46),
#  ('Ramen', 44),
#  ('Mediterranean', 42),
#  ('Fast Food', 42),
#  ('Latin American', 40),
#  ('Music Venues', 40),
#  ('Tacos', 39),
#  ('Soup', 38),
#  ('Breweries', 35),
#  ('Local Flavor', 35),
#  ('Vietnamese', 34),
#  ('Indian', 32),
#  ('Delis', 29),
#  ('Spanish', 28),
#  ('Food Trucks', 27),
#  ('Korean', 27),
#  ('Buffets', 26),
#  ('Chicken Wings', 25),
#  ('Food Stands', 25),
#  ('Ethnic Food', 24),
#  ('Middle Eastern', 23),
#  ('Ice Cream & Frozen Yogurt', 23),
#  ('Shopping', 22),
#  ('Caribbean', 20),
#  ('Soul Food', 20),
#  ('Greek', 18),
#  ('Grocery', 17),
#  ('Hot Dogs', 17),
#  ('Seafood Markets', 17),
#  ('Modern European', 17),
#  ('Active Life', 16),
#  ('Pakistani', 16),
#  ('Food Delivery Services', 16),
#  ('Juice Bars & Smoothies', 15),
#  ('Dim Sum', 15),
#  ('Hotels & Travel', 14),
#  ('Cuban', 13),
#  ('Brazilian', 13),
#  ('Live/Raw Food', 13),
#  ('Brewpubs', 13),
#  ('Donuts', 12),
#  ('Party & Event Planning', 12),
#  ('Canadian (New)', 12),
#  ('Dive Bars', 12),
#  ('Street Vendors', 12),
#  ('Izakaya', 11),
#  ('Hotels', 10),
#  ('Cinema', 10),
#  ('Beer Gardens', 10),
#  ('Chicken Shop', 10),
#  ('Tea Rooms', 10),
#  ('Hawaiian', 10),
#  ('Waffles', 10),
#  ('Halal', 10),
#  ('Meat Shops', 10),
#  ('German', 9),
#  ('Taiwanese', 9),
#  ('Bagels', 9),
#  ('Jazz & Blues', 9),
#  ('Hot Pot', 9),
#  ('Basque', 9),
#  ('Pasta Shops', 9),
#  ('Wineries', 8),
#  ('Belgian', 8),
#  ('Chocolatiers & Shops', 8),
#  ('Creperies', 8),
#  ('Cantonese', 8),
#  ('Irish', 8),
#  ('Smokehouse', 7),
#  ('Turkish', 7),
#  ('Pan Asian', 7),
#  ('Whiskey Bars', 6),
#  ('Amusement Parks', 6),
#  ('Moroccan', 6),
#  ('Dance Clubs', 6),
#  ('Bubble Tea', 6),
#  ('Shopping Centers', 6),
#  ('Flowers & Gifts', 6),
#  ('Fish & Chips', 6),
#  ('British', 6),
#  ('African', 6),
#  ('Malaysian', 6),
#  ('Hookah Bars', 5),
#  ('Argentine', 5),
#  ('New Mexican Cuisine', 5),
#  ('Patisserie/Cake Shop', 5),
#  ('Bowling', 5),
#  ('Irish Pub', 5),
#  ('Dinner Theater', 5),
#  ('Fruits & Veggies', 5),
#  ('Venezuelan', 4),
#  ('Karaoke', 4),
#  ('Performing Arts', 4),
#  ('Coffee Roasteries', 4),
#  ('Custom Cakes', 4),
#  ('Do-It-Yourself Food', 4),
#  ('Piano Bars', 4),
#  ('Szechuan', 4),
#  ('Cheesesteaks', 4),
#  ('Lebanese', 4),
#  ('Butcher', 4),
#  ('Farmers Market', 4),
#  ('Health Markets', 4),
#  ('Laotian', 4),
#  ('Beauty & Spas', 3),
#  ('Puerto Rican', 3),
#  ('Musicians', 3),
#  ('Wine Tasting Room', 3),
#  ('Ethiopian', 3),
#  ('Arcades', 3),
#  ('Art Galleries', 3),
#  ('Cupcakes', 3),
#  ('Gift Shops', 3),
#  ('Wraps', 3),
#  ('Poutineries', 3),
#  ('Scandinavian', 3),
#  ('Fondue', 3),
#  ('Peruvian', 3),
#  ('Home & Garden', 3),
#  ('Arts & Crafts', 3),
#  ('Empanadas', 3),
#  ('Resorts', 2),
#  ('Afghan', 2),
#  ('Dumplings', 2),
#  ('Food Court', 2),
#  ('Home Services', 2),
#  ('Professional Services', 2),
#  ('Public Markets', 2),
#  ('Florists', 2),
#  ('Automotive', 2),
#  ('Gas Stations', 2),
#  ('Japanese Curry', 2),
#  ('Bookstores', 2),
#  ('Books', 2),
#  ('Mags', 2),
#  ('Music & Video', 2),
#  ('Candy Stores', 2),
#  ('Pets', 2),
#  ('Gelato', 2),
#  ('Cambodian', 2),
#  ('Persian/Iranian', 2),
#  ('Local Services', 2),
#  ('Himalayan/Nepalese', 2),
#  ('Cheese Shops', 2),
#  ('Tours', 2),
#  ('Brasseries', 2),
#  ('Eatertainment', 2),
#  ('Mongolian', 2),
#  ('Poke', 2),
#  ('Home Decor', 2),
#  ('Furniture Stores', 2),
#  ('Museums', 2),
#  ('Education', 2),
#  ('Golf', 2),
#  ('Pool Halls', 2),
#  ('Internet Cafes', 2),
#  ('Wedding Planning', 2),
#  ('Conveyor Belt Sushi', 2),
#  ('Polynesian', 2),
#  ('Russian', 2),
#  ('Kitchen & Bath', 2),
#  ('Vacation Rentals', 1),
#  ('Day Spas', 1),
#  ('Aquariums', 1),
#  ('Sports Clubs', 1),
#  ('Real Estate', 1),
#  ('Apartments', 1),
#  ('Tiki Bars', 1),
#  ('Scottish', 1),
#  ('Convenience Stores', 1),
#  ('Filipino', 1),
#  ('Airports', 1),
#  ('Newspapers & Magazines', 1),
#  ('Used Bookstore', 1),
#  ('Imported Food', 1),
#  ('Hong Kong Style Cafe', 1),
#  ('Falafel', 1),
#  ('French Southwest', 1),
#  ('Bed & Breakfast', 1),
#  ('Community Service/Non-Profit', 1),
#  ('Comedy Clubs', 1),
#  ('Singaporean', 1),
#  ('Wedding Chapels', 1),
#  ('Cafeteria', 1),
#  ('Yakiniku', 1),
#  ('Cosmetics & Beauty Supply', 1),
#  ('Office Cleaning', 1),
#  ('Tree Services', 1),
#  ('Organic Stores', 1),
#  ('Acai Bowls', 1),
#  ('Egyptian', 1),
#  ('Bar Crawl', 1),
#  ('Pet Sitting', 1),
#  ('Pet Services', 1),
#  ('Shaved Ice', 1),
#  ('Art Museums', 1),
#  ('Cigar Bars', 1),
#  ('Portuguese', 1),
#  ('Parks', 1),
#  ('Botanical Gardens', 1),
#  ('Cooking Classes', 1),
#  ('Bangladeshi', 1),
#  ('Bistros', 1),
#  ('Canteen', 1),
#  ('Colombian', 1),
#  ('Polish', 1),
#  ('Ukrainian', 1),
#  ('Cooking Schools', 1),
#  ('Specialty Schools', 1),
#  ('Macarons', 1),
#  ('Kosher', 1),
#  ('Appliances', 1),
#  ('Armenian', 1),
#  ('Uzbek', 1),
#  ('Cideries', 1),
#  ('Bartenders', 1),
#  ('Personal Chefs', 1),
#  ('Arabian', 1),
#  ('Champagne Bars', 1),
#  ('Fischbroetchen', 1),
#  ('Shoe Stores', 1),
#  ('Fashion', 1),
#  ('Dominican', 1)]

# %%
selected_categories = [x[0] for x in category_dict.items() 
                       if x[1] > restaurants_sub.shape[0]*0.05 and x[0] not in ['Restaurants', 'Food']]
# selected_categories = set(selected_categories).union(set(['']))
print("Selected categories:  ", selected_categories)

for sc in selected_categories:
    col_name = re.sub(r"[^a-zA-Z0-9()]+", '_', sc.lower()).replace('(', '').replace(')', '')
    restaurants_sub["{}_{}".format('cat', col_name)] = 0
    selected_idx = restaurants_sub['categories'].apply(lambda x: False if x is None else sc in x)
    restaurants_sub.loc[selected_idx, "{}_{}".format('cat', col_name)] = 1
restaurants_sub.head()
# Out:
# Selected categories:   ['Sandwiches', 'Breakfast & Brunch', 'Seafood', 'Italian', 'Beer', 'Wine & Spirits', 'Cocktail Bars', 'Gluten-Free', 'Nightlife', 'Bars', 'Salad', 'Japanese', 'Desserts', 'Event Planning & Services', 'American (Traditional)', 'Southern', 'Sushi Bars', 'American (New)', 'Coffee & Tea', 'Burgers', 'Mexican', 'Barbeque', 'Cafes', 'Wine Bars', 'Steakhouses', 'Asian Fusion', 'Pizza', 'Vegetarian', 'Specialty Food']
#                 business_id                            name  \
# 29   jGennaZUr2MsJyRhijNBfA                 Legal Sea Foods
# 113  XDv29FffNd2dWnDOtZP-wg                   Sapporo Ramen
# 147  bP6goJODwRnM3AVy45Kn9w  Papi's Cuban & Caribbean Grill
# 149  vecuat0jOia-CJveW3ngDw          Schmidt's Sausage Haus
# 312  6Y0lQh4O-9JCutgyuMNq0g                       Loca Luna
#
#                       address       city state postal_code   latitude  \
# 29            1 Harborside Dr     Boston    MA       02128  42.363442
# 113    1815 Massachusetts Ave  Cambridge    MA       02140  42.387212
# 147  216 Ponce De Leon Ave NE    Atlanta    GA       30308  33.772758
# 149          240 E Kossuth St   Columbus    OH       43206  39.946268
# 312      550 Amsterdam Ave NE    Atlanta    GA       30306  33.788608
#
#      longitude  stars  review_count  ...  cat_burgers cat_mexican  \
# 29  -71.025781    3.5           856  ...            0           0
# 113 -71.118532    3.5           635  ...            0           0
# 147 -84.380375    4.0          1001  ...            0           0
# 149 -82.991044    4.0          1354  ...            0           0
# 312 -84.369091    3.5           658  ...            0           0
#
#     cat_barbeque cat_cafes  cat_wine_bars  cat_steakhouses  cat_asian_fusion  \
# 29             0         0              0                0                 0
# 113            0         0              0                0                 0
# 147            0         0              0                0                 0
# 149            0         0              0                0                 0
# 312            0         0              0                0                 0
#
#      cat_pizza  cat_vegetarian  cat_specialty_food
# 29           0               0                   0
# 113          0               0                   0
# 147          0               0                   0
# 149          0               0                   0
# 312          0               0                   0
#
# [5 rows x 71 columns]

# %%
restaurants_sub.to_csv('../data/restaurants2.csv', index = False)

# %% [markdown]
# ## Preprocess Users

# %%
rusers_sub = rusers_sub.reset_index(drop=True).copy()
rusers_sub['elite'] = rusers_sub['elite'].apply(lambda x: 1 if len(x) > 0 else 0)

# %%
rusers_sub
# Out:
#                     user_id     name  review_count        yelping_since  \
# 0    1jXmzuIFKxTnEnR0pxO0Hg    Clara           299  2010-10-01 17:29:36
# 1    CQUDh80m48xnzUkx-X5NAw    David          4205  2008-12-29 21:03:01
# 2    e_YQl5LBR7Gdrp_1vdj1yQ   Shaina           671  2007-07-31 19:21:58
# 3    D8TvYz5Cy5-4V-LuD5nXvQ   Chiqui           478  2011-08-05 14:19:44
# 4    Vlab9b73R5qPLIv6tE4DJA     Tara           955  2007-03-19 18:33:14
# ..                      ...      ...           ...                  ...
# 903  V8oCtUzsdHA_Z9QpGaHCBg    Helen           666  2012-04-09 06:16:20
# 904  ezM7052Nk608iuDnunmTfA   Justin           532  2014-08-20 00:57:09
# 905  C_eD0VF2OZi2rvUUQom3hQ     Anna           304  2011-06-23 22:44:10
# 906  koFIut32RUnYVY08N96slQ  Shannon           174  2015-05-20 00:09:22
# 907  GcnnOSvSExurETu0LO9JIA   Amanda           113  2015-06-05 00:46:46
#
#      useful  funny   cool  elite  \
# 0       381    106    121      1
# 1     21059   8906  14640      1
# 2      1509    646    870      1
# 3      2115   1544   1614      0
# 4      3140   2130   1800      1
# ..      ...    ...    ...    ...
# 903    1166    290    507      1
# 904    3373   1730   2637      1
# 905     502     45    215      1
# 906     891    453    642      1
# 907      22      3     12      0
#
#                                                friends  fans  ...  \
# 0    VGfzq5na6LZUwxwWO5eVLA, 35uHDsVOEsWbLdEg8Ttobg...    23  ...
# 1    WnJlu4mpNtVxNQ2SM6GmvQ, 3BqKBuvY09lissdY_soI6w...   575  ...
# 2    tuyr32-Drc86VsXdPZaBcQ, oIUOyrMfDCE0gUXjt3F15A...    57  ...
# 3    InDrrRvQ9f732YGPX4Ixmg, G-mMQLhruEVkevL5gPhzhg...    61  ...
# 4    O8siifzoJNwb-Wfjyf_veg, LboXWlcBzR-jmrnH-FpNbw...    90  ...
# ..                                                 ...   ...  ...
# 903  OQRWbRdi5Ki-seb4uBi7FA, otENkVmXbClU-aZSTZ8dIQ...   104  ...
# 904  S5208fDRftxFMl5EzGTjow, cW7cD0n5EwDK_kyfIKV3-g...    54  ...
# 905  unkC6mSSTTnwJHEpUv7muQ, p-nsSxznzJgeAmAWSLzf5A...    23  ...
# 906  2VM9xpyjz_4EJ1RAUx-ugA, q-O7E8f0kv7vE_l4vljZ3g...    27  ...
# 907                             f1MFQxTZAWJnRQdrouLg_A     0  ...
#
#      compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0                  8                   2                6                0
# 1                149                 140               66              287
# 2                 14                  10               22               18
# 3                 18                   4                4                1
# 4                 21                  12               17                4
# ..               ...                 ...              ...              ...
# 903                6                   5                1                0
# 904               11                   6                2                0
# 905                4                   0                0                0
# 906                2                   3                0                0
# 907                0                   0                0                0
#
#      compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0                 17                47               30                30
# 1               1034              1529             1572              1572
# 2                 69               101              129               129
# 3                164               281              348               348
# 4                 54               106              175               175
# ..               ...               ...              ...               ...
# 903               19                38               36                36
# 904               53               413              227               227
# 905                9                12               12                12
# 906               13                21               56                56
# 907                0                 0                0                 0
#
#      compliment_writer  compliment_photos
# 0                    4                  1
# 1                  492                180
# 2                   37                  7
# 3                   76                 92
# 4                   60                 11
# ..                 ...                ...
# 903                 32                 59
# 904                126                128
# 905                  4                  7
# 906                 54                  5
# 907                  1                  0
#
# [908 rows x 22 columns]

# %%
selected_users = set(rusers_sub['user_id'])
f = open('data/friend_network.txt', 'w')
for i in range(rusers_sub.shape[0]):
    uid = rusers_sub.loc[i, 'user_id'].strip()
    friends = rusers_sub.loc[i, 'friends']
    for fid in friends.split(','):
        if fid in selected_users:
            f.write("{} {}\n".format(uid, fid))
f.close()

# %%
rusers = rusers_sub.drop(['name', 'friends'], axis = 1)
rusers.to_csv("../data/users2.csv", index = False)

# %% [markdown]
# ### Tips & Reviews

# %%
tips_union.to_csv("../data/tips2.csv", index = False)
rreviews_union.to_csv('../data/reviews2.csv', index = False)
