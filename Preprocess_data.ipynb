# %%
import time
import re
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from sklearn.preprocessing import LabelEncoder

import scipy
from scipy.sparse import csr_matrix

data_path = './data/'
if not os.path.exists(data_path):
    os.makedirs(data_path)

# %% [markdown]
# ## Loading Data

# %%
start_time = time.time()
business = pd.read_json("yelp_dataset/yelp_academic_dataset_business.json", 
                      orient = 'records',
                      lines = True, chunksize = 10000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 2.3642706871032715

# %%
display(business.head())
print(business.shape)
print("Number of business:  {}".format(business['business_id'].nunique()))
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3        1  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
#
#                                           categories  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2  Antiques, Fashion, Used, Vintage & Consignment...
# 3                         Beauty & Spas, Hair Salons
# 4  Gyms, Active Life, Interval Training Gyms, Fit...
#
#                                                hours
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                               None
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# (160585, 14)
# Number of business:  160585

# %%
restaurants = business.loc[business['categories'].apply(lambda x: False if x is None else 'Restaurants' in x ),].copy()
print('Number of restaurants:  ', restaurants.shape[0])
# Out:
# Number of restaurants:   50763

# %% [markdown]
# ### Review

# %%
start_time = time.time()
reviews = pd.read_json("yelp_dataset/yelp_academic_dataset_review.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 69.24591445922852

# %%
display(reviews.head())
print(reviews.shape)
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2  NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4  sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
#
#    stars  useful  funny  cool  \
# 0      4       3      1     1
# 1      4       1      0     0
# 2      5       0      0     0
# 3      2       1      1     1
# 4      4       0      0     0
#
#                                                 text                date
# 0  Apparently Prides Osteria had a rough summer a... 2014-10-11 03:34:02
# 1  This store is pretty good. Not as great as Wal... 2015-07-03 20:38:25
# 2  I called WVM on the recommendation of a couple... 2013-05-28 20:38:06
# 3  I've stayed at many Marriott and Renaissance M... 2010-01-08 02:29:15
# 4  The food is always great here. The service fro... 2011-07-28 18:05:01
# (8635403, 9)

# %%
rreviews = reviews[reviews['business_id'].isin(restaurants['business_id'])]
print(rreviews.shape)
# Out:
# (5574795, 9)

# %% [markdown]
# ### User

# %%
start_time = time.time()
users = pd.read_json("yelp_dataset/yelp_academic_dataset_user.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 38.01014232635498

# %%
display(users.head())
print(users.shape)
print("Number of Users:  {}".format(users['user_id'].nunique()))
# Out:
#                   user_id       name  review_count        yelping_since  \
# 0  q_QQ5kBBwlCcbL1s4NVK3g       Jane          1220  2005-03-14 20:26:35
# 1  dIIKEfOgo0KqUfGQvGikPg       Gabi          2136  2007-08-10 19:01:51
# 2  D6ErcUnFALnCQN4b1W_TlA      Jason           119  2007-02-07 15:47:53
# 3  JnPIjvC0cmooNDfsa9BmXg        Kat           987  2009-02-09 16:14:29
# 4  37Hc8hr3cw0iHLoPzLK6Ow  Christine           495  2008-03-03 04:57:05
#
#    useful  funny   cool                                              elite  \
# 0   15038  10030  11291       2006,2007,2008,2009,2010,2011,2012,2013,2014
# 1   21272  10289  18046  2007,2008,2009,2010,2011,2012,2013,2014,2015,2...
# 2     188    128    130                                          2010,2011
# 3    7234   4722   4035                      2009,2010,2011,2012,2013,2014
# 4    1577    727   1124                                     2009,2010,2011
#
#                                              friends  fans  ...  \
# 0  xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357  ...
# 1  XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...  1025  ...
# 2  GfB6sC4NJQvSI2ewbQrDNA, jhZtzZNNZJOU2YSZ6jPlXQ...    16  ...
# 3  HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...   420  ...
# 4  -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...    47  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0              163                 190              361              147
# 1               87                  94              232               96
# 2                1                   3                0                0
# 3              129                  93              219               90
# 4               19                  32               16               15
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0             1212              5691             2541              2541
# 1             1187              3293             2205              2205
# 2                5                20               31                31
# 3             1120              4510             1566              1566
# 4               77               131              310               310
#
#    compliment_writer  compliment_photos
# 0                815                323
# 1                472                294
# 2                  3                  1
# 3                391                326
# 4                 98                 44
#
# [5 rows x 22 columns]
# (2189457, 22)
# Number of Users:  2189457

# %%
rusers = users[users['user_id'].isin(rreviews['user_id'].unique())]
print(rusers.shape)
# Out:
# (1551310, 22)

# %% [markdown]
# ### Tips

# %%
start_time = time.time()
tips = pd.read_json("yelp_dataset/yelp_academic_dataset_tip.json", 
                      orient = 'records',
                      lines = True, chunksize = 100000).read()
end_time = time.time()
print(end_time - start_time)
# Out:
# 4.769688129425049

# %%
display(tips.head())
print(tips.shape)
# Out:
#                   user_id             business_id  \
# 0  WCjg0jdHXMlwbqS9tZUx8Q  ENwBByjpoa5Gg7tKgxqwLg
# 1  42-Z02y9bABShAGZhuSzrQ  jKO4Og6ucdX2-YCTKQVYjg
# 2  5u7E3LYp_3eB8dLuUBazXQ  9Bto7mky640ocgezVKSfVg
# 3  wDWoMG5N9oI4DJ-p7z8EBg  XWFjKtRGZ9khRGtGg2ZvaA
# 4  JmuFlorjjRshHTKzTwNtgg  mkrx0VhSMU3p3uhyJGCoWA
#
#                                                 text                date  \
# 0                               Carne asada chips... 2011-07-22 19:07:35
# 1  Best happy hour from 3pm to 6pm! $1 off martin... 2014-09-10 07:33:29
# 2  Nice people, skilled staff, clean location - b... 2013-12-13 23:23:41
# 3  1/2-price bowling & the "Very" Old Fashion are... 2017-07-11 23:07:16
# 4  Solid gold's. Great sauna. Great staff, too. E... 2016-11-30 08:46:36
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# (1162119, 5)

# %%
rtips = tips[tips['business_id'].isin(restaurants['business_id'])]
print(rtips.shape)
# Out:
# (810577, 5)

# %% [markdown]
# ## Taking Subsets

# %%
sparsity_score = lambda r, u, b: r.shape[0] / (u.shape[0] * b.shape[0])
print("Current sparsity:  ", sparsity_score(rreviews, rusers, restaurants))
# Out:
# Current sparsity:   7.079181214365046e-05

# %%
# print(restaurants['review_count'].describe())
# plt.plot(np.arange(0, 1, 0.001), np.quantile(restaurants['review_count'], np.arange(0, 1, 0.001)))

# %%
user_review_count = rreviews.groupby(['user_id'])['review_id'].count()
rusers_sub = rusers[rusers['user_id'].isin(user_review_count.index[user_review_count > 10])]

# %%
# Users leave more than 10 reviews
# Restaurants at least receive 114 (third quantile) reviews

# Subset restaurants
restaurants_sub = restaurants[restaurants['review_count'] > 114]
state_count = restaurants.groupby(['state'])['business_id'].count()
restaurants_sub = restaurants_sub[restaurants_sub['state'].isin(state_count.index[state_count > 5])]
rreviews_business = rreviews[rreviews['business_id'].isin(restaurants_sub['business_id'])]

# Subset Users
user_review_count = rreviews_business.groupby(['user_id'])['review_id'].count()
rusers_sub = rusers[rusers['user_id'].isin(user_review_count.index[user_review_count > 10])]

# Subset Reviews
rreviews_users = rreviews[rreviews['user_id'].isin(user_review_count.index[user_review_count>10])]
rreviews_union = rreviews.loc[set(rreviews_business.index).union(rreviews_users.index), ]
rreviews_inter = rreviews.loc[set(rreviews_business.index).intersection(rreviews_users.index), ]


# Subset tips
tips_business = tips[tips['business_id'].isin(restaurants_sub['business_id'])]
tips_users = tips[tips['user_id'].isin(rusers_sub['user_id'])]
tips_union = tips.loc[set(tips_business.index).union(set(tips_users.index)),]

print("Number of restaurants:  ", restaurants_sub.shape[0])
print("Number of users:  ", rusers_sub.shape[0])
print("Number of reviews:  ", rreviews_inter.shape[0])
print("Sparsity:  ", sparsity_score(rreviews_inter, rusers_sub, restaurants_sub))
# Out:
# Number of restaurants:   12665
# Number of users:   60851
# Number of reviews:   1674121
# Sparsity:   0.0021722706300724864

# %% [markdown]
# ## Preprocess Restaurants

# %% [markdown]
# ### Separting Restaurants Attributes

# %%
attributes = defaultdict(int)
for i in restaurants_sub['attributes'].apply(lambda x: None if x is None else x.keys()):
    if i is not None:
        for k in i:
            attributes[k] += 1
attributes
# Out:
# defaultdict(int,
#             {'RestaurantsTakeOut': 12563,
#              'RestaurantsAttire': 12138,
#              'GoodForKids': 12300,
#              'BikeParking': 11958,
#              'OutdoorSeating': 12506,
#              'Ambience': 12348,
#              'Caters': 12100,
#              'RestaurantsReservations': 12393,
#              'RestaurantsDelivery': 12550,
#              'HasTV': 12348,
#              'RestaurantsGoodForGroups': 12359,
#              'BusinessAcceptsCreditCards': 11907,
#              'NoiseLevel': 12220,
#              'ByAppointmentOnly': 2101,
#              'RestaurantsPriceRange2': 12581,
#              'WiFi': 12406,
#              'BusinessParking': 12605,
#              'Alcohol': 12378,
#              'GoodForMeal': 11241,
#              'DogsAllowed': 6285,
#              'Music': 2983,
#              'BusinessAcceptsBitcoin': 2880,
#              'GoodForDancing': 2337,
#              'BestNights': 2701,
#              'HappyHour': 6871,
#              'RestaurantsTableService': 7768,
#              'WheelchairAccessible': 5313,
#              'CoatCheck': 2164,
#              'Smoking': 1831,
#              'BYOBCorkage': 2172,
#              'Corkage': 2041,
#              'DriveThru': 1386,
#              'BYOB': 1575,
#              'RestaurantsCounterService': 32,
#              'Open24Hours': 24,
#              'AgesAllowed': 9,
#              'DietaryRestrictions': 32})

# %%
# Select attributes having more than 1000 restaurants

selected_attributes = [k for k in attributes if attributes[k] > 1000]
for at in selected_attributes:
    restaurants["{}_{}".format('attr', at)] = 0
    selected_idx = restaurants_sub['categories'].apply(lambda x: False if x is None else at in x)
    restaurants_sub.loc[selected_idx, "{}_{}".format('attr', at)] = 1

# %%
restaurants_sub.head()
# Out:
#                business_id                         name  \
# 1   tCbdrRPZA0oiIYSmHG3J0w      Flying Elephants at PDX
# 5   D4JtQNTI4X3KcbzacDJsMw          Bob Likes Thai Food
# 13  ufCxltuh56FF4-ZFZ6cVhg               Sister Honey's
# 29  jGennaZUr2MsJyRhijNBfA              Legal Sea Foods
# 41  NRPemqVb4qpWFF0Avq_6OQ  Eurasia Sushi Bar & Seafood
#
#                     address       city state postal_code   latitude  \
# 1       7000 NE Airport Way   Portland    OR       97218  45.588906
# 5              3755 Main St  Vancouver    BC         V5V  49.251342
# 13        247 E Michigan St    Orlando    FL       32806  28.513265
# 29          1 Harborside Dr     Boston    MA       02128  42.363442
# 41  7101 W Hwy 71, Ste C-13     Austin    TX       78735  30.234533
#
#      longitude  stars  review_count  ...  attr_BestNights attr_HappyHour  \
# 1  -122.593331    4.0           126  ...              NaN            NaN
# 5  -123.101333    3.5           169  ...              NaN            NaN
# 13  -81.374707    4.5           135  ...              NaN            NaN
# 29  -71.025781    3.5           856  ...              NaN            NaN
# 41  -97.877262    4.5           395  ...              NaN            NaN
#
#    attr_RestaurantsTableService attr_WheelchairAccessible  attr_CoatCheck  \
# 1                           NaN                       NaN             NaN
# 5                           NaN                       NaN             NaN
# 13                          NaN                       NaN             NaN
# 29                          NaN                       NaN             NaN
# 41                          NaN                       NaN             NaN
#
#     attr_Smoking  attr_BYOBCorkage  attr_Corkage  attr_DriveThru  attr_BYOB
# 1            NaN               NaN           NaN             NaN        NaN
# 5            NaN               NaN           NaN             NaN        NaN
# 13           NaN               NaN           NaN             NaN        NaN
# 29           NaN               NaN           NaN             NaN        NaN
# 41           NaN               NaN           NaN             NaN        NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Separating Restaurants Categories

# %%
category_dict = defaultdict(int)
for cat in restaurants_sub['categories']:
    for c in cat.split(','):
        category_dict[c.strip()] += 1
sorted(category_dict.items(), key=lambda x: x[1], reverse = True)
# Out:
# [('Restaurants', 12665),
#  ('Food', 3873),
#  ('Nightlife', 3868),
#  ('Bars', 3735),
#  ('American (Traditional)', 2391),
#  ('American (New)', 2326),
#  ('Breakfast & Brunch', 1922),
#  ('Sandwiches', 1536),
#  ('Seafood', 1279),
#  ('Italian', 1148),
#  ('Pizza', 1140),
#  ('Mexican', 1133),
#  ('Burgers', 1046),
#  ('Japanese', 985),
#  ('Coffee & Tea', 934),
#  ('Event Planning & Services', 886),
#  ('Sushi Bars', 863),
#  ('Cocktail Bars', 850),
#  ('Salad', 833),
#  ('Chinese', 751),
#  ('Asian Fusion', 731),
#  ('Desserts', 693),
#  ('Cafes', 672),
#  ('Vegetarian', 625),
#  ('Pubs', 580),
#  ('Beer', 560),
#  ('Wine & Spirits', 560),
#  ('Steakhouses', 557),
#  ('Wine Bars', 536),
#  ('Thai', 531),
#  ('Specialty Food', 527),
#  ('Gluten-Free', 524),
#  ('Caterers', 516),
#  ('Bakeries', 515),
#  ('Mediterranean', 491),
#  ('Sports Bars', 490),
#  ('Barbeque', 476),
#  ('Vegan', 450),
#  ('Fast Food', 404),
#  ('Diners', 380),
#  ('Arts & Entertainment', 373),
#  ('Lounges', 368),
#  ('Vietnamese', 362),
#  ('Soup', 346),
#  ('Tex-Mex', 342),
#  ('Southern', 331),
#  ('Indian', 328),
#  ('Chicken Wings', 309),
#  ('Venues & Event Spaces', 290),
#  ('Delis', 283),
#  ('Noodles', 282),
#  ('Gastropubs', 278),
#  ('Middle Eastern', 268),
#  ('Tapas/Small Plates', 266),
#  ('Food Trucks', 264),
#  ('French', 261),
#  ('Korean', 259),
#  ('Beer Bar', 250),
#  ('Comfort Food', 239),
#  ('Latin American', 236),
#  ('Greek', 232),
#  ('Breweries', 212),
#  ('Food Stands', 199),
#  ('Music Venues', 199),
#  ('Juice Bars & Smoothies', 188),
#  ('Buffets', 188),
#  ('Ice Cream & Frozen Yogurt', 185),
#  ('Tapas Bars', 182),
#  ('Ramen', 174),
#  ('Ethnic Food', 169),
#  ('Local Flavor', 156),
#  ('Tacos', 153),
#  ('Food Delivery Services', 147),
#  ('Halal', 146),
#  ('Hotels & Travel', 142),
#  ('Pakistani', 141),
#  ('Cajun/Creole', 136),
#  ('Bagels', 131),
#  ('Shopping', 129),
#  ('Hot Dogs', 128),
#  ('Grocery', 122),
#  ('Caribbean', 117),
#  ('Canadian (New)', 114),
#  ('Spanish', 113),
#  ('Hotels', 111),
#  ('Bubble Tea', 109),
#  ('Irish', 108),
#  ('Dim Sum', 108),
#  ('Dive Bars', 94),
#  ('Hawaiian', 92),
#  ('Taiwanese', 81),
#  ('Active Life', 81),
#  ('Soul Food', 78),
#  ('Modern European', 75),
#  ('Street Vendors', 75),
#  ('Donuts', 74),
#  ('Cuban', 66),
#  ('Hot Pot', 65),
#  ('Chicken Shop', 64),
#  ('Lebanese', 63),
#  ('Fish & Chips', 62),
#  ('Seafood Markets', 61),
#  ('Poke', 61),
#  ('Brazilian', 59),
#  ('Szechuan', 59),
#  ('Brewpubs', 57),
#  ('German', 54),
#  ('Wraps', 53),
#  ('Tea Rooms', 53),
#  ('Karaoke', 52),
#  ('Turkish', 51),
#  ('Dance Clubs', 50),
#  ('British', 50),
#  ('Party & Event Planning', 49),
#  ('Pan Asian', 48),
#  ('Beer Gardens', 47),
#  ('Meat Shops', 46),
#  ('Creperies', 46),
#  ('Coffee Roasteries', 44),
#  ('Cantonese', 44),
#  ('Falafel', 44),
#  ('Jazz & Blues', 43),
#  ('Waffles', 42),
#  ('Irish Pub', 42),
#  ('Live/Raw Food', 42),
#  ('African', 41),
#  ('Persian/Iranian', 40),
#  ('Pasta Shops', 39),
#  ('Health Markets', 38),
#  ('Cheesesteaks', 36),
#  ('Malaysian', 35),
#  ('Arcades', 35),
#  ('Peruvian', 34),
#  ('Fruits & Veggies', 34),
#  ('Ethiopian', 32),
#  ('New Mexican Cuisine', 32),
#  ('Pool Halls', 32),
#  ('Cinema', 31),
#  ('Hookah Bars', 30),
#  ('Izakaya', 30),
#  ('Whiskey Bars', 29),
#  ('Moroccan', 29),
#  ('Bowling', 29),
#  ('Himalayan/Nepalese', 28),
#  ('Shopping Centers', 28),
#  ('Wineries', 27),
#  ('Smokehouse', 26),
#  ('Mongolian', 26),
#  ('Cupcakes', 25),
#  ('Cheese Shops', 25),
#  ('Internet Cafes', 25),
#  ('Farmers Market', 25),
#  ('Venezuelan', 24),
#  ('Patisserie/Cake Shop', 22),
#  ('Basque', 22),
#  ('Food Court', 22),
#  ('Do-It-Yourself Food', 22),
#  ('Gelato', 22),
#  ('Kosher', 21),
#  ('Butcher', 21),
#  ('Brasseries', 21),
#  ('Organic Stores', 21),
#  ('Acai Bowls', 21),
#  ('Custom Cakes', 20),
#  ('Fondue', 20),
#  ('International Grocery', 20),
#  ('Belgian', 20),
#  ('Kebab', 19),
#  ('Amusement Parks', 19),
#  ('Colombian', 19),
#  ('Bistros', 18),
#  ('Puerto Rican', 18),
#  ('Performing Arts', 18),
#  ('Chocolatiers & Shops', 18),
#  ('Laotian', 18),
#  ('Tours', 17),
#  ('Art Galleries', 17),
#  ('Singaporean', 16),
#  ('Convenience Stores', 16),
#  ('Fashion', 16),
#  ('Gay Bars', 15),
#  ('Cambodian', 15),
#  ('Teppanyaki', 15),
#  ('Argentine', 14),
#  ('Pets', 14),
#  ('Tiki Bars', 14),
#  ('Home & Garden', 14),
#  ('Filipino', 14),
#  ('Bangladeshi', 14),
#  ('Dinner Theater', 13),
#  ('Beauty & Spas', 12),
#  ('Home Services', 12),
#  ('Arts & Crafts', 12),
#  ('Flowers & Gifts', 12),
#  ('Books', 12),
#  ('Mags', 12),
#  ('Music & Video', 12),
#  ('Automotive', 11),
#  ('Conveyor Belt Sushi', 11),
#  ('Adult Entertainment', 11),
#  ('Wedding Planning', 11),
#  ('Resorts', 10),
#  ('Candy Stores', 10),
#  ('Education', 10),
#  ('Imported Food', 10),
#  ('Cafeteria', 10),
#  ('Empanadas', 10),
#  ('Comedy Clubs', 10),
#  ('Piano Bars', 10),
#  ('Shaved Ice', 10),
#  ('Shanghainese', 10),
#  ('Poutineries', 10),
#  ('Portuguese', 9),
#  ('Beverage Store', 9),
#  ('Personal Chefs', 9),
#  ('Arabian', 9),
#  ('Local Services', 9),
#  ('Australian', 9),
#  ('Scandinavian', 9),
#  ('Bed & Breakfast', 9),
#  ('Armenian', 9),
#  ('Eatertainment', 9),
#  ('Salvadoran', 8),
#  ('Dominican', 8),
#  ('Polish', 8),
#  ('Real Estate', 8),
#  ('Fitness & Instruction', 8),
#  ('Home Decor', 8),
#  ('Indonesian', 8),
#  ('Wine Tasting Room', 7),
#  ('Burmese', 7),
#  ('Afghan', 7),
#  ('Golf', 7),
#  ('Champagne Bars', 7),
#  ('Cooking Classes', 7),
#  ('Furniture Stores', 7),
#  ('Kitchen & Bath', 7),
#  ('Cideries', 7),
#  ('Macarons', 6),
#  ('Specialty Schools', 6),
#  ('Cooking Schools', 6),
#  ('Dumplings', 6),
#  ('South African', 6),
#  ('Egyptian', 6),
#  ('Professional Services', 6),
#  ('Department Stores', 6),
#  ('International', 5),
#  ('Day Spas', 5),
#  ('Ethnic Grocery', 5),
#  ('Museums', 5),
#  ('Tobacco Shops', 5),
#  ('Appliances', 5),
#  ('Scottish', 5),
#  ('Gift Shops', 5),
#  ('Tuscan', 5),
#  ('Parks', 5),
#  ('Pop-Up Restaurants', 5),
#  ('Transportation', 5),
#  ('Austrian', 4),
#  ('Vacation Rentals', 4),
#  ('Pet Adoption', 4),
#  ('Themed Cafes', 4),
#  ('Kombucha', 4),
#  ('Laser Tag', 4),
#  ('Public Markets', 4),
#  ('Tasting Classes', 4),
#  ('Wine Tasting Classes', 4),
#  ('Health & Medical', 4),
#  ('Japanese Curry', 4),
#  ('Hobby Shops', 4),
#  ('Bookstores', 4),
#  ("Men's Clothing", 4),
#  ('Syrian', 4),
#  ('Religious Organizations', 4),
#  ('Pet Stores', 4),
#  ('Russian', 4),
#  ('Boat Charters', 3),
#  ('Boating', 3),
#  ('Drugstores', 3),
#  ('Musicians', 3),
#  ('Pop-up Shops', 3),
#  ('Ukrainian', 3),
#  ('Community Service/Non-Profit', 3),
#  ('Tabletop Games', 3),
#  ('Apartments', 3),
#  ('Florists', 3),
#  ('Auto Repair', 3),
#  ('Hong Kong Style Cafe', 3),
#  ('Gas Stations', 3),
#  ('Outlet Stores', 3),
#  ('Uzbek', 3),
#  ('Cigar Bars', 3),
#  ("Women's Clothing", 3),
#  ('Videos & Video Game Rental', 3),
#  ('Social Clubs', 3),
#  ('Animal Shelters', 3),
#  ('Airport Lounges', 3),
#  ('Cabaret', 3),
#  ('Wholesale Stores', 3),
#  ('Pancakes', 3),
#  ('Casinos', 3),
#  ('Delicatessen', 3),
#  ('Herbs & Spices', 3),
#  ('Public Services & Government', 3),
#  ('Boat Tours', 2),
#  ('Pool & Billiards', 2),
#  ('Towing', 2),
#  ('Mini Golf', 2),
#  ('Personal Shopping', 2),
#  ('Honey', 2),
#  ('Trinidadian', 2),
#  ('CSA', 2),
#  ('Outdoor Furniture Stores', 2),
#  ('Mattresses', 2),
#  ('Antiques', 2),
#  ('Kids Activities', 2),
#  ('Airports', 2),
#  ('Used Bookstore', 2),
#  ('Car Wash', 2),
#  ('Yelp Events', 2),
#  ('Recreation Centers', 2),
#  ('Guest Houses', 2),
#  ('Martial Arts', 2),
#  ('Chinese Martial Arts', 2),
#  ('Vinyl Records', 2),
#  ('Dog Parks', 2),
#  ('Czech', 2),
#  ('Property Management', 2),
#  ('Speakeasies', 2),
#  ('Ranches', 2),
#  ('Farms', 2),
#  ('Bar Crawl', 2),
#  ('Cosmetics & Beauty Supply', 2),
#  ('Pretzels', 2),
#  ('Hakka', 2),
#  ('Hungarian', 2),
#  ('Electronics', 2),
#  ('Financial Services', 2),
#  ('Art Museums', 2),
#  ('Massage', 2),
#  ('Sporting Goods', 2),
#  ('Accessories', 2),
#  ('Gyms', 2),
#  ('Bartenders', 2),
#  ('Sri Lankan', 2),
#  ('Botanical Gardens', 2),
#  ('Polynesian', 2),
#  ('Landmarks & Historical Buildings', 2),
#  ('Yoga', 2),
#  ('Travel Services', 2),
#  ('Shoe Stores', 2),
#  ('Hostels', 2),
#  ('Aquariums', 1),
#  ('Rotisserie Chicken', 1),
#  ('Observatories', 1),
#  ('Keys & Locksmiths', 1),
#  ('Eritrean', 1),
#  ('Festivals', 1),
#  ('Amateur Sports Teams', 1),
#  ('Sports Clubs', 1),
#  ('Hair Salons', 1),
#  ('Axe Throwing', 1),
#  ('Golf Lessons', 1),
#  ('Hair Removal', 1),
#  ('Waxing', 1),
#  ('Nail Salons', 1),
#  ('Massage Therapy', 1),
#  ('Newspapers & Magazines', 1),
#  ('Bulgarian', 1),
#  ('Swiss Food', 1),
#  ('Tai Chi', 1),
#  ('Meaderies', 1),
#  ('French Southwest', 1),
#  ('Dance Restaurants', 1),
#  ('Mortgage Brokers', 1),
#  ('Brewing Supplies', 1),
#  ('Electronics Repair', 1),
#  ('Nurseries & Gardening', 1),
#  ('Czech/Slovakian', 1),
#  ('Synagogues', 1),
#  ('Used', 1),
#  ('Vintage & Consignment', 1),
#  ('Wedding Chapels', 1),
#  ('Wine Tours', 1),
#  ('Scavenger Hunts', 1),
#  ('Yakiniku', 1),
#  ('Office Cleaning', 1),
#  ('Tree Services', 1),
#  ('Mauritius', 1),
#  ('Catalan', 1),
#  ('Trainers', 1),
#  ('Calabrian', 1),
#  ('Iberian', 1),
#  ('Comic Books', 1),
#  ('Pet Sitting', 1),
#  ('Pet Services', 1),
#  ('Lakes', 1),
#  ('Napoletana', 1),
#  ('Bikes', 1),
#  ('Bike Repair/Maintenance', 1),
#  ('Go Karts', 1),
#  ('Dry Cleaning & Laundry', 1),
#  ('Laundry Services', 1),
#  ('Laundromat', 1),
#  ('Educational Services', 1),
#  ('Cheese Tasting Classes', 1),
#  ('Food Tours', 1),
#  ('Swimming Pools', 1),
#  ('Music & DVDs', 1),
#  ('Beer Garden', 1),
#  ('Senegalese', 1),
#  ('Real Estate Services', 1),
#  ('Canteen', 1),
#  ('Special Education', 1),
#  ('Baseball Fields', 1),
#  ('Stadiums & Arenas', 1),
#  ('Supernatural Readings', 1),
#  ('Toy Stores', 1),
#  ('Cultural Center', 1),
#  ('Weight Loss Centers', 1),
#  ('Distilleries', 1),
#  ('Donairs', 1),
#  ('Party Supplies', 1),
#  ('Departments of Motor Vehicles', 1),
#  ('Sports Wear', 1),
#  ('Motorcycle Gear', 1),
#  ('Building Supplies', 1),
#  ('Pub Food', 1),
#  ('Eyewear & Opticians', 1),
#  ('Ethical Grocery', 1),
#  ('Cannabis Clinics', 1),
#  ('Jewelry', 1),
#  ('Skating Rinks', 1),
#  ('Taxis', 1),
#  ('Limos', 1),
#  ('Airport Shuttles', 1),
#  ('Coffee & Tea Supplies', 1),
#  ('Beer Tours', 1),
#  ('Cards & Stationery', 1),
#  ('Pita', 1),
#  ('Oriental', 1),
#  ('Fischbroetchen', 1),
#  ('Strip Clubs', 1),
#  ('Team Building Activities', 1),
#  ('Escape Games', 1),
#  ('Veterinarians', 1),
#  ('Train Stations', 1),
#  ('Kiosk', 1)]

# %%
selected_categories = [x[0] for x in category_dict.items() if x[1] > 500 and x[0] != 'Restaurants']
selected_categories

for sc in selected_categories:
    col_name = re.sub(r"[^a-zA-Z0-9()]+", '_', sc.lower()).replace('(', '').replace(')', '')
    restaurants_sub["{}_{}".format('cat', col_name)] = 0
    selected_idx = restaurants_sub['categories'].apply(lambda x: False if x is None else sc in x)
    restaurants_sub.loc[selected_idx, "{}_{}".format('cat', col_name)] = 1
restaurants_sub.head()
# Out:
#                business_id                         name  \
# 1   tCbdrRPZA0oiIYSmHG3J0w      Flying Elephants at PDX
# 5   D4JtQNTI4X3KcbzacDJsMw          Bob Likes Thai Food
# 13  ufCxltuh56FF4-ZFZ6cVhg               Sister Honey's
# 29  jGennaZUr2MsJyRhijNBfA              Legal Sea Foods
# 41  NRPemqVb4qpWFF0Avq_6OQ  Eurasia Sushi Bar & Seafood
#
#                     address       city state postal_code   latitude  \
# 1       7000 NE Airport Way   Portland    OR       97218  45.588906
# 5              3755 Main St  Vancouver    BC         V5V  49.251342
# 13        247 E Michigan St    Orlando    FL       32806  28.513265
# 29          1 Harborside Dr     Boston    MA       02128  42.363442
# 41  7101 W Hwy 71, Ste C-13     Austin    TX       78735  30.234533
#
#      longitude  stars  review_count  ...  cat_pizza cat_caterers cat_pubs  \
# 1  -122.593331    4.0           126  ...          0            0        0
# 5  -123.101333    3.5           169  ...          0            0        0
# 13  -81.374707    4.5           135  ...          0            0        0
# 29  -71.025781    3.5           856  ...          0            0        0
# 41  -97.877262    4.5           395  ...          0            0        0
#
#    cat_event_planning_services  cat_mexican  cat_steakhouses  cat_wine_bars  \
# 1                            0            0                0              0
# 5                            0            0                0              0
# 13                           0            0                0              0
# 29                           0            0                0              0
# 41                           0            0                0              0
#
#     cat_specialty_food  cat_asian_fusion  cat_burgers
# 1                    0                 0            0
# 5                    0                 0            0
# 13                   0                 0            0
# 29                   0                 0            0
# 41                   0                 0            0
#
# [5 rows x 80 columns]

# %%
restaurants_sub.to_csv('data/restaurants.csv', index = False)

# %% [markdown]
# ## Preprocess Users

# %%
rusers_sub = rusers_sub.reset_index(drop=True).copy()
rusers_sub['elite'] = rusers_sub['elite'].apply(lambda x: 1 if len(x) > 0 else 0)

# %%
rusers_sub
# Out:
#                       user_id               name  review_count  \
# 0      q_QQ5kBBwlCcbL1s4NVK3g               Jane          1220
# 1      dIIKEfOgo0KqUfGQvGikPg               Gabi          2136
# 2      JnPIjvC0cmooNDfsa9BmXg                Kat           987
# 3      37Hc8hr3cw0iHLoPzLK6Ow          Christine           495
# 4      n-QwITZYrXlKQRiV30MqNg            Natasha           229
# ...                       ...                ...           ...
# 60846  Xvik-lYFpaPnW8lpzHd89A              Karin            49
# 60847  1uMNrBqq9Au2w_xXN1HuPA  Graham Wellington            15
# 60848  pSSTYS9dkkqPGpcck5mFcQ              David           184
# 60849  fcl2-83fUbIvzMQCZKWKKA               Josh            54
# 60850  9N-FlJRqFqO6ThoJShBSwQ             Taniah             1
#
#              yelping_since  useful  funny   cool  elite  \
# 0      2005-03-14 20:26:35   15038  10030  11291      1
# 1      2007-08-10 19:01:51   21272  10289  18046      1
# 2      2009-02-09 16:14:29    7234   4722   4035      1
# 3      2008-03-03 04:57:05    1577    727   1124      1
# 4      2008-06-25 14:53:17     476    101    140      1
# ...                    ...     ...    ...    ...    ...
# 60846  2011-06-18 21:57:49       9      2      4      0
# 60847  2016-10-31 20:09:44      19     14      0      0
# 60848  2016-12-05 00:03:34     102     20     52      0
# 60849  2007-02-23 17:56:54      39      1     14      0
# 60850  2017-05-19 16:21:13       0      0      0      0
#
#                                                  friends  fans  ...  \
# 0      xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357  ...
# 1      XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...  1025  ...
# 2      HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...   420  ...
# 3      -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...    47  ...
# 4      2ptwW5l68069vNtW8J-WOg, 4TVFuz8L4TsDtx_ObSin9g...    17  ...
# ...                                                  ...   ...  ...
# 60846                             38Nmkq0zyrFKqSrTyEhsVA     0  ...
# 60847                                               None     0  ...
# 60848                                               None     3  ...
# 60849  lRLCZGMx--uxPI_9up5fGA, UlYXVV0Ls5UwJzUqt_m7mQ...     3  ...
# 60850                                               None     0  ...
#
#        compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0                  163                 190              361              147
# 1                   87                  94              232               96
# 2                  129                  93              219               90
# 3                   19                  32               16               15
# 4                    4                   3                0                0
# ...                ...                 ...              ...              ...
# 60846                0                   0                0                0
# 60847                1                   0                0                0
# 60848                0                   0                0                0
# 60849                1                   0                0                0
# 60850                0                   0                0                0
#
#        compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0                 1212              5691             2541              2541
# 1                 1187              3293             2205              2205
# 2                 1120              4510             1566              1566
# 3                   77               131              310               310
# 4                   10                15               24                24
# ...                ...               ...              ...               ...
# 60846                0                 0                0                 0
# 60847                1                 1                0                 0
# 60848                0                 1                3                 3
# 60849                0                 0                2                 2
# 60850                0                 0                0                 0
#
#        compliment_writer  compliment_photos
# 0                    815                323
# 1                    472                294
# 2                    391                326
# 3                     98                 44
# 4                     16                  2
# ...                  ...                ...
# 60846                  0                  1
# 60847                  0                  0
# 60848                  1                  1
# 60849                  2                  0
# 60850                  0                  0
#
# [60851 rows x 22 columns]

# %%
selected_users = set(rusers_sub['user_id'])
f = open('data/friend_network.txt', 'w')
for i in range(rusers_sub.shape[0]):
    uid = rusers_sub.loc[i, 'user_id'].strip()
    friends = rusers_sub.loc[i, 'friends']
    for fid in friends.split(','):
        if fid in selected_users:
            f.write("{} {}".format(uid, fid))
f.close()

# %%
rusers = rusers_sub.drop(['name', 'friends'], axis = 1)
rusers.to_csv("data/users.csv", index = False)

# %% [markdown]
# ### Tips & Reviews

# %%
tips_union.to_csv("data/tips.csv", index = False)
rreviews_union.to_csv('data/reviews.csv', index = False)
